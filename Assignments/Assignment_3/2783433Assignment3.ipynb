# %% [markdown]
# # Knowledge and Data: Practical Assignment 3
# ## RDF Data, RDFS knowledge and inferencing

# %% [markdown]
# YOUR NAME: Ionut-Valentin Moise
#
# YOUR VUNetID: imo213
#
# *(If you do not provide your name and VUNetID we will not accept your submission).*

# %% [markdown]
# ### Learning objectives
#
# At the end of this exercise you should be able to:
#
# 1. Access local an external data via SPARQL both from within a python programming environment and stand-alone with a GUI, such as [YASGUI](https://yasgui.triply.cc/), and this way integrate data from different sources
# 2. Model your own first knowledge base, in this case an RDF Schema knowledge graph
# 3. Implement inference rules

# %% [markdown]
# Follow this Notebook step-by-step.
#
# Of course, you can do the exercises in any Programming Editor of your liking.
# But you do not have to. Feel free to simply write code in the Notebook. When
# everythink is filled in and works, safe the Notebook and submit it
# as a Jupyter Notebook, i.e. with an ipynb extension. Please use as name of the
# Notebook your studentID+Assignment3.ipynb.
#
#
# We will not evaluate the programming style of your solutions. Yet we do look whether your solutions suggests an understanding, and whether they yield the correct output.
#
# Note that all notebooks will automatically be checked for plagiarism: while similar answers can be expected, it is not allowed to directly copy the solutions from fellow students or TAs, or from the examples discussed during the lectures. Similarly, sharing your solutions with your peers is not allowed.
#
# **IMPORTANT: Submit this notebook after finishing the assignment. It is not necessary to submit the created turtle files**

# %% [markdown]
# Before you start, you need to:
#
# - **Install the *rdflib* Python package:** *pip install rdflib* (should already be installed from the previous assignment)
# - **Install the *SPARQLWrapper* Python package:** *pip install SPARQLWrapper*
# - **Install the free edition of the GraphDB Triplestore:** please follow this short [GraphDB tutorial](https://github.com/ucds-vu/knowledge-data-vu/blob/master/Tutorials/Preliminaries/tutorial-GraphDB.md).
#
# Then, add the file example-from-slides.ttl to a newly created database, say called assignment-3.
#
# **Note that you should have an active internet connection to run the code in this notebook. Also, if, for some external reason (ie internet and/or system issues), you cannot access the SPARQL endpoint, then report this to a TA as soon as possible!**

# %%
# install library
# %pip install SPARQLWrapper
# Out:
# Requirement already satisfied: SPARQLWrapper in /Users/ionutmoise/opt/anaconda3/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: rdflib>=6.1.1 in /Users/ionutmoise/opt/anaconda3/lib/python3.9/site-packages (from SPARQLWrapper) (6.2.0)
# Requirement already satisfied: pyparsing in /Users/ionutmoise/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.0.4)
# Requirement already satisfied: setuptools in /Users/ionutmoise/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (61.2.0)
# Requirement already satisfied: isodate in /Users/ionutmoise/opt/anaconda3/lib/python3.9/site-packages (from rdflib>=6.1.1->SPARQLWrapper) (0.6.1)
# Requirement already satisfied: six in /Users/ionutmoise/opt/anaconda3/lib/python3.9/site-packages (from isodate->rdflib>=6.1.1->SPARQLWrapper) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task 1: (35 points) Integrate Local and External Data

# %% [markdown]
# You can integrate SPARQL queries into your Python code by using the *RDFLib* and *SPARQLWrapper* libraries.
#
# The following code accesses the DBPedia knowledge graph using its SPARQL endpoint, and returns the result of the SPARQL query requesting all the labels asserted to Amsterdam (test it!)

# %%
# This code only works if you are online.
# If, for some reason, you cannot get this to work, then please contact a TA

from rdflib import Graph, RDF, RDFS, Namespace, Literal, URIRef
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?cityName
    WHERE { 
        <http://dbpedia.org/resource/Amsterdam> rdfs:label ?cityName 
    }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    print(result["cityName"]["value"])
# Out:
# Amsterdam
# أمستردام
# Amsterdam
# Amsterdam
# Amsterdam
# Άμστερνταμ
# Amsterdamo
# Ámsterdam
# Amsterdam
# Amstardam
# Amsterdam
# Amsterdam
# Amsterdam
# 암스테르담
# アムステルダム
# Amsterdam
# Amsterdam
# Амстердам
# Amesterdão
# Amsterdam
# Амстердам
# 阿姆斯特丹

# %% [markdown]
# For your convenience, we already wrote the following functions that might be useful to complete this task.
# In addition, we have loaded and printed the 'example-from-slides.ttl' dataset.

# %%
from rdflib import Graph, RDF, Namespace, Literal, URIRef
from SPARQLWrapper import SPARQLWrapper, JSON


# Loads the data from a certain file given as input in Turtle syntax into the Graph g  
# -------------------------
def load_graph(graph, filename):
    with open(filename, 'r') as f:
        graph.parse(f, format='turtle')
        

# Prints a certain graph given as input in Turtle syntax
# if your output shows byte string (ie, b'...') you must add '.decode()' to the print statements:
#    print(myGraph.serialize(format='turtle').decode())
# -------------------------
def serialize_graph(myGraph):
     print(myGraph.serialize(format='turtle'))
        

# Saves the Graph g in Turtle syntax to a certain file given as input
# -------------------------
def save_graph(myGraph, filename):
    with open(filename, 'w') as f:
        myGraph.serialize(filename, format='turtle')
        
    
# Changes the namespace of a certain URI given as input to a DBpedia URI 
# Example: transformToDBR("http://example.com/kad2020/Amsterdam") returns "http://dbpedia.org/resource/Amsterdam"
# -------------------------
def transformToDBR(uri):
    if isinstance(uri, Literal):
        # changes the literal to uppercase so that the object with the same name refers 
        # to an object and not the string
        return uri.upper()
    components = g.namespace_manager.compute_qname(uri)
    return "http://dbpedia.org/resource/%s"%(components[2])

# -------------------------

g = Graph()
load_graph(g, 'example-from-slides.ttl')
serialize_graph(g)


# Don't forget to run this cell before continuing the task.
# Out:
# @prefix ex: <http://example.com/kad/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# ex:Netherlands a ex:Country ;
#     ex:contains ex:Ijsselmeer ;
#     ex:containsCity ex:Rotterdam ;
#     ex:hasCapital ex:Amsterdam ;
#     ex:hasName "The Netherlands" ;
#     ex:neighbours ex:Belgium .
#
# ex:hasCapital rdfs:range ex:Capital ;
#     rdfs:subPropertyOf ex:containsCity .
#
# ex:neighbours rdfs:subPropertyOf ex:closeBy .
#
# ex:Amsterdam a ex:Capital ;
#     ex:closeBy ex:Germany .
#
# ex:Belgium a ex:Country .
#
# ex:EuropeanCountry rdfs:subClassOf ex:Country .
#
# ex:Germany a ex:EuropeanCountry ;
#     ex:hasCapital ex:Berlin .
#
# ex:closeBy rdfs:domain ex:Location ;
#     rdfs:range ex:Location .
#
# ex:containsCity rdfs:domain ex:Country ;
#     rdfs:range ex:City ;
#     rdfs:subPropertyOf ex:contains .
#
# ex:Capital rdfs:subClassOf ex:City .
#
# ex:City rdfs:subClassOf ex:Location .
#
# ex:Country rdfs:subClassOf ex:Location .

# %% [markdown]
# ### A: Write a SPARQL query that finds all the cities in the dataset
#
# As you cannot directly use class City, you will have to find those cities in the dataset (example-from-slides.ttl) using implicit information that can be deduced from the domain and ranges of the relations (e.g. things in a hasCapital relation are capitals and a capital is a city, etc.).
#
# Save all the cities returned from the SPARQL query into the empty set "cities".

# %%
cities = set()

sparql = SPARQLWrapper("http://Ionuts-MacBook-Pro.local:7200/repositories/KnowledgeAndData")
sparql.setQuery("""
    PREFIX ex: <http://example.com/kad/>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    SELECT DISTINCT ?city
    WHERE { 
        { 
            # ?city rdf:type ex:Capital .  
        }
        UNION
        {
            # ?something ex:hasCapital ?city .
        }
        UNION
        {
            # ?something ex:containsCity ?city .
        }
    }

""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    city_uri = result["city"]["value"]
    dbpedia_uri = transformToDBR(city_uri)
    cities.add(dbpedia_uri)

    
for city in cities:
    print(city)
# Out:
# http://dbpedia.org/resource/Amsterdam
# http://dbpedia.org/resource/Berlin
# http://dbpedia.org/resource/Rotterdam

# %% [markdown]
# ### B: For each city, find from DBpedia its longitude & latitude, and its number of inhabitants (if available)
#
# Don't forget to adapt the namespace of the cities in your dataset when querying DBpedia, using the above function *transformToDBR(uri)*. Also note that namespaces should never use the *https* protocol.
#
# The empty graph h should only contain the triples extracted from DBpedia, but added to the URIs with the 'ex' namespace.
# An example of a triple in h is the following triple:
#
#        ex:Amsterdam dbo:populationTotal "872680"^^xsd:nonNegativeInteger .

# %%
h = Graph()

dbo = Namespace("http://dbpedia.org/ontology/")
geo = Namespace("http://www.w3.org/2003/01/geo/wgs84_pos#")

h.bind("ex", "http://example.com/kad/")
h.bind("dbo", dbo)
h.bind("geo", geo)

for city in cities:
    city = transformToDBR(city)
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")

    sparql.setQuery("""
        PREFIX ex: <http://example.com/kad/>
        PREFIX geo: <http://www.w3.org/2003/01/geo/wgs84_pos#>
        PREFIX dbo: <http://dbpedia.org/ontology/>

        SELECT ?populationTotal ?lat ?long 

        WHERE { 

            {<"""+city+"""> dbo:populationTotal ?populationTotal.}
            {<"""+city+"""> geo:lat ?lat.}
            {<"""+city+"""> geo:long ?long.}

            }

            """)
    
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()
    
    for result in results["results"]["bindings"]:
        h.add((URIRef(city), geo.lat, Literal(result["lat"]["value"])))
        h.add((URIRef(city), geo.long, Literal(result["long"]["value"])))
        population = result["populationTotal"]["value"]
        if population:
            h.add((URIRef(city), dbo.populationTotal, Literal(result["populationTotal"]["value"])))


serialize_graph(h)
# Out:
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
#
# <http://dbpedia.org/resource/Amsterdam> dbo:populationTotal "907976" ;
#     geo:lat "52.3667" ;
#     geo:long "4.9" .
#
# <http://dbpedia.org/resource/Berlin> dbo:populationTotal "3677472" ;
#     geo:lat "52.52" ;
#     geo:long "13.405" .
#
# <http://dbpedia.org/resource/Rotterdam> dbo:populationTotal "651157" ;
#     geo:lat "51.9167" ;
#     geo:long "4.5" .

# %% [markdown]
# ### C: Save your results
#
# - Merge the triples from example-from-slides.ttl with the information extracted from DBpedia. See the [documentation](https://rdflib.readthedocs.io/en/stable/merging.html) on how to accomplish this.
# - Save all these triples into a new file 'extended-example.ttl'. **It is not necessary to submit this file**
# - Print all triples in Turtle Syntax.

# %%
new_graph = Graph()

new_graph = g + h

save_graph(new_graph, 'extended-example.ttl')

serialize_graph(new_graph)
# Out:
# @prefix dbo: <http://dbpedia.org/ontology/> .
# @prefix dbr: <http://dbpedia.org/resource/> .
# @prefix ex: <http://example.com/kad/> .
# @prefix geo: <http://www.w3.org/2003/01/geo/wgs84_pos#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#
# dbr:Amsterdam dbo:populationTotal "907976" ;
#     geo:lat "52.3667" ;
#     geo:long "4.9" .
#
# dbr:Berlin dbo:populationTotal "3677472" ;
#     geo:lat "52.52" ;
#     geo:long "13.405" .
#
# dbr:Rotterdam dbo:populationTotal "651157" ;
#     geo:lat "51.9167" ;
#     geo:long "4.5" .
#
# ex:Netherlands a ex:Country ;
#     ex:contains ex:Ijsselmeer ;
#     ex:containsCity ex:Rotterdam ;
#     ex:hasCapital ex:Amsterdam ;
#     ex:hasName "The Netherlands" ;
#     ex:neighbours ex:Belgium .
#
# ex:hasCapital rdfs:range ex:Capital ;
#     rdfs:subPropertyOf ex:containsCity .
#
# ex:neighbours rdfs:subPropertyOf ex:closeBy .
#
# ex:Amsterdam a ex:Capital ;
#     ex:closeBy ex:Germany .
#
# ex:Belgium a ex:Country .
#
# ex:EuropeanCountry rdfs:subClassOf ex:Country .
#
# ex:Germany a ex:EuropeanCountry ;
#     ex:hasCapital ex:Berlin .
#
# ex:closeBy rdfs:domain ex:Location ;
#     rdfs:range ex:Location .
#
# ex:containsCity rdfs:domain ex:Country ;
#     rdfs:range ex:City ;
#     rdfs:subPropertyOf ex:contains .
#
# ex:Capital rdfs:subClassOf ex:City .
#
# ex:City rdfs:subClassOf ex:Location .
#
# ex:Country rdfs:subClassOf ex:Location .

# %% [markdown]
# ## Task 2: (25 points)  Implement Basic Inferencing Rules

# %% [markdown]
# In the lecture we showed that the RDFS inference rules can be used to infer new knowledge. For example, infer class membership based on _rdfs:domain_ or infer relationships between subjects and objects based on _rdfs:subPropertyOf_.
#
# Create rules to inference class membership based on the RDF Schema language features
# *	For example: infer that an instance belongs to a class because of domain and range restrictions
# *	For example: infer that an instance belongs to a (super)class because it also belongs to a subclass
#
# We implemented the __rdfs2__ rule. You should implement the 5 following remaining rules:
#
# *     (rdfs2) If G contains the triples (aaa rdfs:domain xxx.) and (uuu aaa yyy.)  then infer the triple (uuu rdf:type xxx.)
# *     (rdfs3) If G contains the triples (aaa rdfs:range xxx.) and (uuu aaa vvv.) then infer the triple (vvv rdf:type xxx .)
# *     (rdfs5) If G contains the triples (uuu rdfs:subPropertyOf vvv.) and (vvv rdfs:subPropertyOf xxx.) then infer the triple
# (uuu rdfs:subPropertyOf xxx.)
# *     (rdfs7) If G contains the triples (aaa rdfs:subPropertyOf bbb.) and (uuu aaa yyy.) then infer the triple (uuu bbb yyy)
# *     (rdfs9) If G contains the triples (uuu rdfs:subClassOf xxx.) and (vvv rdf:type uuu.) then infer the triple
#  (vvv rdf:type xxx.)   -> this one was not mentioned in the lecture, but is a very important one.
# *     (rdfs11) If G contains the triples (uuu rdfs:subClassOf vvv.) and (vvv rdfs:subClassOf xxx.) then infer the triple
# (uuu rdfs:subClassOf xxx.)
#
#
# Run your rule reasoner on your knowledge graph. If you have implemented everything correctly, you should find exactly 17 inferences.

# %%
def myRDFSreasoner(myGraph):
    inferredTriples = 0
    for sbj, prd, obj in myGraph:

        # --- rdfs2 ---
        if (prd.eq(URIRef("http://www.w3.org/2000/01/rdf-schema#domain"))):
            generator = myGraph.subject_objects(URIRef(sbj))
            for s, o in generator:
                inferredTriples += 1
                print("(rdfs 2) ", s, "rdf:type", obj)
        
        # --- rdfs3 ---
        if (prd.eq(URIRef("http://www.w3.org/2000/01/rdf-schema#range"))):
            generator = myGraph.subject_objects(URIRef(sbj))
            for s, o in generator:
                inferredTriples += 1
                print("(rdfs 3) ", o, "rdf:type", obj)

        
        # --- rdfs5 ---
        if (prd.eq(URIRef("http://www.w3.org/2000/01/rdf-schema#subPropertyOf"))):
            generator = myGraph.subject_objects(URIRef(prd))
            for s, o in generator:
                if obj == s:
                    inferredTriples += 1
                    print("(rdfs 5) ", s, "rdf:subPropertyOf", obj)
        
        
        # --- rdfs7 ---
        if (prd.eq(URIRef("http://www.w3.org/2000/01/rdf-schema#subPropertyOf"))):
            generator = myGraph.subject_objects(URIRef(sbj))
            for s, o in generator:
                inferredTriples += 1
                print("(rdfs 7) ", s, obj, o)
                   
        
        # --- rdfs9 ---
        if (prd.eq(URIRef("http://www.w3.org/2000/01/rdf-schema#subClassOf"))):
            generator = myGraph.subject_objects(RDF.type)
            for s, o in generator:
                if sbj == o:
                    inferredTriples += 1
                    print("(rdfs 9) ", s, "rdf:type", obj)
        
        
        # --- rdfs11 ---
        if (prd.eq(URIRef("http://www.w3.org/2000/01/rdf-schema#subClassOf"))):
            generator = myGraph.subject_objects(URIRef(prd))
            for s, o in generator:
                if obj == s:
                    inferredTriples += 1
                    print("(rdfs 11) ", sbj, "rdf:subClassOf", o)
        
    print("---------------------------------")
    print("Number of inferred triples:", inferredTriples)
    print("---------------------------------")
    
myRDFSreasoner(g)  # test your reasoner
# Out:
# (rdfs 3)  http://example.com/kad/Amsterdam rdf:type http://example.com/kad/Capital
# (rdfs 3)  http://example.com/kad/Berlin rdf:type http://example.com/kad/Capital
# (rdfs 9)  http://example.com/kad/Amsterdam rdf:type http://example.com/kad/City
# (rdfs 11)  http://example.com/kad/Capital rdf:subClassOf http://example.com/kad/Location
# (rdfs 2)  http://example.com/kad/Netherlands rdf:type http://example.com/kad/Country
# (rdfs 2)  http://example.com/kad/Amsterdam rdf:type http://example.com/kad/Location
# (rdfs 7)  http://example.com/kad/Netherlands http://example.com/kad/contains http://example.com/kad/Rotterdam
# (rdfs 3)  http://example.com/kad/Rotterdam rdf:type http://example.com/kad/City
# (rdfs 9)  http://example.com/kad/Netherlands rdf:type http://example.com/kad/Location
# (rdfs 9)  http://example.com/kad/Belgium rdf:type http://example.com/kad/Location
# (rdfs 5)  http://example.com/kad/containsCity rdf:subPropertyOf http://example.com/kad/containsCity
# (rdfs 7)  http://example.com/kad/Netherlands http://example.com/kad/containsCity http://example.com/kad/Amsterdam
# (rdfs 7)  http://example.com/kad/Germany http://example.com/kad/containsCity http://example.com/kad/Berlin
# (rdfs 3)  http://example.com/kad/Germany rdf:type http://example.com/kad/Location
# (rdfs 7)  http://example.com/kad/Netherlands http://example.com/kad/closeBy http://example.com/kad/Belgium
# (rdfs 9)  http://example.com/kad/Germany rdf:type http://example.com/kad/Country
# (rdfs 11)  http://example.com/kad/EuropeanCountry rdf:subClassOf http://example.com/kad/Location
# ---------------------------------
# Number of inferred triples: 17
# ---------------------------------

# %% [markdown]
# ## Task 3: (20 points) Build your very own RDFS knowledge graph.

# %% [markdown]
# Define a small RDF Schema vocabulary in Turtle. You can choose your own domain (e.g. movies, geography, sports), as long as it hasn't been used as an example during the lectures. The following rules must be respected:
# *	The schema should define at least 4 classes, 4 properties, and 4 instances.
# *   The properties should be used to relate the instances (i.e., object-type relations)
# *	The instances should be members of at least one of the 4 defined classes
# *	All resources should have an rdfs:label attribute in a suitable language.
#
# You should use (at least) the following language features of RDF and RDFS:
# * 	rdf:type (or 'a')
# * 	rdfs:subClassOf
# * 	rdfs:subPropertyOf
# * 	rdfs:domain and rdfs:range
# *	rdfs:label
#
# Be sure to define the 'rdf:' and 'rdfs:' namespace prefixes for RDF and RDF Schema in your file (perhaps have a look at http://prefix.cc)
#
# For creating your vocabulary you should add the axioms directly (programatically) to your Knowledge Graph as you did last week.
#
# Play around with the inference rules you have created in the previous task to make sure that you added some implicit knowledge, that becomes "visible" via inferencing (this will be useful for the next task).
#
# Finally:
# - Add the knowledge you created into the RDFlib graph datastructure *myRDFSgraph*,
# - Print *myRDFSgraph* in Turtle so that we can check your "design"
# - Save *myRDFSgraph* into a new file 'myRDFSgraph.ttl' (it is not necessary to submit this file)

# %%
myRDFSgraph = Graph()


# Define RDF and RDFS namespaces
sport = Namespace("http://example.com/sports#")
rdf = Namespace("http://www.w3.org/1999/02/22-rdf-syntax-ns#")
rdfs = Namespace("http://www.w3.org/2000/01/rdf-schema#")

myRDFSgraph.bind("sport", sport)

# Define classes
myRDFSgraph.add((sport.Diving, rdf.type, rdfs.Class))
myRDFSgraph.add((sport.Swimming, rdf.type, rdfs.Class))
myRDFSgraph.add((sport.Boxing, rdf.type, rdfs.Class))
myRDFSgraph.add((sport.Wrestling, rdf.type, rdfs.Class))

myRDFSgraph.add((sport.Sport, rdf.type, rdfs.Class))

# Define properties
myRDFSgraph.add((sport.involvesAthlete, rdf.type, rdf.Property))
myRDFSgraph.add((sport.hasReferee, rdf.type, rdf.Property))
myRDFSgraph.add((sport.requiresSkill, rdf.type, rdf.Property))
myRDFSgraph.add((sport.isJudged, rdf.type, rdf.Property))

# Add labels for resources
myRDFSgraph.add((sport.Diving, rdfs.label, Literal("Diving", lang="en")))
myRDFSgraph.add((sport.Swimming, rdfs.label, Literal("Swimming", lang="en")))
myRDFSgraph.add((sport.Boxing, rdfs.label, Literal("Boxing", lang="en")))
myRDFSgraph.add((sport.Wrestling, rdfs.label, Literal("Wrestling", lang="en")))
myRDFSgraph.add((sport.involvesAthlete, rdfs.label, Literal("Involves Athlete", lang="en")))
myRDFSgraph.add((sport.hasReferee, rdfs.label, Literal("Has Referee", lang="en")))
myRDFSgraph.add((sport.requiresSkill, rdfs.label, Literal("Requires Skill", lang="en")))
myRDFSgraph.add((sport.isJudged, rdfs.label, Literal("Is Judged", lang="en")))

# Define axioms
myRDFSgraph.add((sport.Diving, sport.hasSportsProperty, sport.involvesAthlete))
myRDFSgraph.add((sport.Swimming, sport.hasSportsProperty, sport.involvesAthlete))
myRDFSgraph.add((sport.Boxing, sport.hasSportsProperty, sport.involvesAthlete))
myRDFSgraph.add((sport.Wrestling, sport.hasSportsProperty, sport.involvesAthlete))

myRDFSgraph.add((sport.involvesAthlete, rdfs.subClassOf, sport.sportsProperty))
myRDFSgraph.add((sport.hasReferee, rdfs.subClassOf, sport.sportsProperty))
myRDFSgraph.add((sport.requiresSkill, rdfs.subClassOf, sport.sportsProperty))
myRDFSgraph.add((sport.isJudged, rdfs.subClassOf, sport.sportsProperty))

myRDFSgraph.add((sport.Diving, sport.hasReferee, Literal("Yes", lang="en")))
myRDFSgraph.add((sport.Swimming, sport.hasReferee, Literal("Yes", lang="en")))
myRDFSgraph.add((sport.Boxing, sport.hasReferee, Literal("Yes", lang="en")))
myRDFSgraph.add((sport.Wrestling, sport.hasReferee, Literal("Yes", lang="en")))

myRDFSgraph.add((sport.Diving, sport.requiresSkill, Literal("High", lang="en")))
myRDFSgraph.add((sport.Swimming, sport.requiresSkill, Literal("Moderate", lang="en")))
myRDFSgraph.add((sport.Boxing, sport.requiresSkill, Literal("High", lang="en")))
myRDFSgraph.add((sport.Wrestling, sport.requiresSkill, Literal("High", lang="en")))

myRDFSgraph.add((sport.Diving, sport.isJudged, Literal("Yes", lang="en")))
myRDFSgraph.add((sport.Swimming, sport.isJudged, Literal("Yes", lang="en")))
myRDFSgraph.add((sport.Boxing, sport.isJudged, Literal("Yes", lang="en")))
myRDFSgraph.add((sport.Wrestling, sport.isJudged, Literal("Yes", lang="en")))

myRDFSgraph.add((sport.isContact_Sport, rdfs.range, rdfs.Sport))
myRDFSgraph.add((sport.hasSportsProperty, rdfs.subPropertyOf, rdfs.sportsProperty))
myRDFSgraph.add((sport.sportsProperty, rdfs.subClassOf, sport.Sport))

myRDFSgraph.add((sport.hasReferee, rdfs.subPropertyOf, sport.hasSportsProperty))
myRDFSgraph.add((sport.isJudged, rdfs.subPropertyOf, sport.hasSportsProperty))
myRDFSgraph.add((sport.requiresSkill, rdfs.subPropertyOf, sport.hasSportsProperty))
myRDFSgraph.add((sport.involvesAthlete, rdfs.subPropertyOf, sport.hasSportsProperty))

myRDFSgraph.add((sport.Boxing, sport.isContact_Sport, sport.Sport))
myRDFSgraph.add((sport.Wrestling, sport.isContact_Sport, sport.Sport))



# Print the RDF graph in Turtle format
print("RDF Graph in Turtle:")
serialize_graph(myRDFSgraph)

# Save the RDF graph in a specific file
save_graph(myRDFSgraph, 'myRDFSgraph.ttl')

print("Now let's check what we can infer from your knowledge graph...")
print("The more rules you cover, the better!")
myRDFSreasoner(myRDFSgraph)
# Out:
# RDF Graph in Turtle:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix sport: <http://example.com/sports#> .
#
# sport:Boxing a rdfs:Class ;
#     rdfs:label "Boxing"@en ;
#     sport:hasReferee "Yes"@en ;
#     sport:hasSportsProperty sport:involvesAthlete ;
#     sport:isContact_Sport sport:Sport ;
#     sport:isJudged "Yes"@en ;
#     sport:requiresSkill "High"@en .
#
# sport:Diving a rdfs:Class ;
#     rdfs:label "Diving"@en ;
#     sport:hasReferee "Yes"@en ;
#     sport:hasSportsProperty sport:involvesAthlete ;
#     sport:isJudged "Yes"@en ;
#     sport:requiresSkill "High"@en .
#
# sport:Sport a rdfs:Class .
#
# sport:Swimming a rdfs:Class ;
#     rdfs:label "Swimming"@en ;
#     sport:hasReferee "Yes"@en ;
#     sport:hasSportsProperty sport:involvesAthlete ;
#     sport:isJudged "Yes"@en ;
#     sport:requiresSkill "Moderate"@en .
#
# sport:Wrestling a rdfs:Class ;
#     rdfs:label "Wrestling"@en ;
#     sport:hasReferee "Yes"@en ;
#     sport:hasSportsProperty sport:involvesAthlete ;
#     sport:isContact_Sport sport:Sport ;
#     sport:isJudged "Yes"@en ;
#     sport:requiresSkill "High"@en .
#
# sport:hasReferee a rdf:Property ;
#     rdfs:label "Has Referee"@en ;
#     rdfs:subClassOf sport:sportsProperty ;
#     rdfs:subPropertyOf sport:hasSportsProperty .
#
# sport:isContact_Sport rdfs:range rdfs:Sport .
#
# sport:isJudged a rdf:Property ;
#     rdfs:label "Is Judged"@en ;
#     rdfs:subClassOf sport:sportsProperty ;
#     rdfs:subPropertyOf sport:hasSportsProperty .
#
# sport:requiresSkill a rdf:Property ;
#     rdfs:label "Requires Skill"@en ;
#     rdfs:subClassOf sport:sportsProperty ;
#     rdfs:subPropertyOf sport:hasSportsProperty .
#
# sport:hasSportsProperty rdfs:subPropertyOf rdfs:sportsProperty .
#
# sport:involvesAthlete a rdf:Property ;
#     rdfs:label "Involves Athlete"@en ;
#     rdfs:subClassOf sport:sportsProperty ;
#     rdfs:subPropertyOf sport:hasSportsProperty .
#
# sport:sportsProperty rdfs:subClassOf sport:Sport .
#
#
# Now let's check what we can infer from your knowledge graph...
# The more rules you cover, the better!
# (rdfs 11)  http://example.com/sports#involvesAthlete rdf:subClassOf http://example.com/sports#Sport
# (rdfs 11)  http://example.com/sports#hasReferee rdf:subClassOf http://example.com/sports#Sport
# (rdfs 11)  http://example.com/sports#isJudged rdf:subClassOf http://example.com/sports#Sport
# (rdfs 3)  http://example.com/sports#Sport rdf:type http://www.w3.org/2000/01/rdf-schema#Sport
# (rdfs 3)  http://example.com/sports#Sport rdf:type http://www.w3.org/2000/01/rdf-schema#Sport
# (rdfs 5)  http://example.com/sports#hasSportsProperty rdf:subPropertyOf http://example.com/sports#hasSportsProperty
# (rdfs 7)  http://example.com/sports#Diving http://example.com/sports#hasSportsProperty High
# (rdfs 7)  http://example.com/sports#Boxing http://example.com/sports#hasSportsProperty High
# (rdfs 7)  http://example.com/sports#Wrestling http://example.com/sports#hasSportsProperty High
# (rdfs 7)  http://example.com/sports#Swimming http://example.com/sports#hasSportsProperty Moderate
# (rdfs 5)  http://example.com/sports#hasSportsProperty rdf:subPropertyOf http://example.com/sports#hasSportsProperty
# (rdfs 7)  http://example.com/sports#Diving http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Swimming http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Boxing http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Wrestling http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Diving http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete
# (rdfs 7)  http://example.com/sports#Swimming http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete
# (rdfs 7)  http://example.com/sports#Boxing http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete
# (rdfs 7)  http://example.com/sports#Wrestling http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete
# (rdfs 5)  http://example.com/sports#hasSportsProperty rdf:subPropertyOf http://example.com/sports#hasSportsProperty
# (rdfs 7)  http://example.com/sports#Diving http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Swimming http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Boxing http://example.com/sports#hasSportsProperty Yes
# (rdfs 7)  http://example.com/sports#Wrestling http://example.com/sports#hasSportsProperty Yes
# (rdfs 5)  http://example.com/sports#hasSportsProperty rdf:subPropertyOf http://example.com/sports#hasSportsProperty
# (rdfs 11)  http://example.com/sports#requiresSkill rdf:subClassOf http://example.com/sports#Sport
# ---------------------------------
# Number of inferred triples: 26
# ---------------------------------

# %% [markdown]
# ## Task 4 (20 points) Compare local inferences with GraphDB results

# %% [markdown]
# Upload *myRDFSgraph.ttl* to GraphDB (check [the GraphDB tutorial](https://github.com/ucds-vu/knowledge-data-vu/blob/master/Tutorials/Preliminaries/tutorial-GraphDB.md) before starting to work with GraphDB).
#
# Formulate two different SPARQL queries, and write a Python code that executes these queries over your GraphDB SPARQL endpoint (check example of Task 1).
#
# **Each SPARQL query should return a _different type_ of inferred knowledge** (at least one triple that was not explicitly asserted in the graph).
#
# Specify below next to your query (using a comment '# ...') which type of RDFS rule is the GraphDB reasoner using to infer this answer (rdfs2, rdfs3, rdfs5, rdfs7, rdfs9, rdfs11).

# %%
# Get your GraphDB repository URL (setup -> repositories -> repository url) and 
# assign it to the variable 'myEndpoint' below. 

myEndpoint = "http://Ionuts-MacBook-Pro.local:7200/repositories/KnowledgeAndData"  
sparql = SPARQLWrapper(myEndpoint)

# %%
# Query 1 - Specify which RDFS rule are you testing:  We are going to test rdfs7

# Check example of Task 1 on how to query remote SPARQL endpoints

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    SELECT DISTINCT ?subject ?predicate ?object 
        WHERE {
            # ?something rdfs:subPropertyOf ?predicate .
            # ?subject ?something ?object .
            FILTER (?subject != ?object)
    }
""")


sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    sbj = result["subject"]["value"]
    prd = result["predicate"]["value"]
    obj = result["object"]["value"]
    print(f"{sbj} {prd} {obj} .")
# Out:
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Property http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#TransitiveProperty .
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#TransitiveProperty .
# http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#SymmetricProperty .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#TransitiveProperty .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#SymmetricProperty .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#TransitiveProperty .
# http://proton.semanticweb.org/protonsys#transitiveOver http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#inverseOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#inverseOf http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#SymmetricProperty .
# http://www.w3.org/2000/01/rdf-schema#Literal http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2001/XMLSchema#nonNegativeInteger http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2001/XMLSchema#nonNegativeInteger http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://www.w3.org/2000/01/rdf-schema#Datatype http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#first http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#differentFrom http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2002/07/owl#SymmetricProperty .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#rest http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#nil http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#subject http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#object http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#value http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#List http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#Container http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://www.w3.org/2001/XMLSchema#string http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2001/XMLSchema#string http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Datatype .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#_1 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#_1 http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty .
# http://example.com/kad/hasName http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/kad/neighbours http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/kad/hasCapital http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/kad/closeBy http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/kad/containsCity http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/kad/contains http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#Boxing http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#hasReferee http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#hasReferee http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#hasSportsProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#involvesAthlete http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#involvesAthlete http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#isContact_Sport http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#Sport http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#Sport http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Sport .
# http://example.com/sports#isJudged http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#isJudged http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#requiresSkill http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://example.com/sports#requiresSkill http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#Diving http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#Swimming http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#Wrestling http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://example.com/sports#sportsProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#Sport http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#sportsProperty http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/2002/07/owl#equivalentProperty http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subPropertyOf .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#subClassOf .
# http://www.w3.org/2000/01/rdf-schema#isDefinedBy http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#seeAlso .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#_1 http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#member .
# http://example.com/sports#hasReferee http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://example.com/sports#hasSportsProperty .
# http://example.com/sports#hasReferee http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#sportsProperty .
# http://example.com/sports#hasSportsProperty http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#sportsProperty .
# http://example.com/sports#involvesAthlete http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://example.com/sports#hasSportsProperty .
# http://example.com/sports#involvesAthlete http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#sportsProperty .
# http://example.com/sports#isJudged http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://example.com/sports#hasSportsProperty .
# http://example.com/sports#isJudged http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#sportsProperty .
# http://example.com/sports#requiresSkill http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://example.com/sports#hasSportsProperty .
# http://example.com/sports#requiresSkill http://www.w3.org/2000/01/rdf-schema#subPropertyOf http://www.w3.org/2000/01/rdf-schema#sportsProperty .
# http://www.w3.org/2001/XMLSchema#nonNegativeInteger http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2000/01/rdf-schema#Datatype http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/1999/02/22-rdf-syntax-ns#Property .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Container .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Container .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Container .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2001/XMLSchema#string http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#Literal .
# http://example.com/sports#hasReferee http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#Sport .
# http://example.com/sports#hasReferee http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#sportsProperty .
# http://example.com/sports#involvesAthlete http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#Sport .
# http://example.com/sports#involvesAthlete http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#sportsProperty .
# http://example.com/sports#isJudged http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#Sport .
# http://example.com/sports#isJudged http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#sportsProperty .
# http://example.com/sports#requiresSkill http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#Sport .
# http://example.com/sports#requiresSkill http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#sportsProperty .
# http://example.com/sports#sportsProperty http://www.w3.org/2000/01/rdf-schema#subClassOf http://example.com/sports#Sport .
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#first http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#rest http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#subject http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#object http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement .
# http://www.w3.org/2000/01/rdf-schema#subClassOf http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#domain http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/2002/07/owl#equivalentClass http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Class .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#rest http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/1999/02/22-rdf-syntax-ns#List .
# http://www.w3.org/2000/01/rdf-schema#comment http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://www.w3.org/2000/01/rdf-schema#label http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Literal .
# http://example.com/sports#isContact_Sport http://www.w3.org/2000/01/rdf-schema#range http://www.w3.org/2000/01/rdf-schema#Sport .
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://proton.semanticweb.org/protonsys#transitiveOver http://www.w3.org/2000/01/rdf-schema#subClassOf .
# http://example.com/sports#Boxing http://www.w3.org/2000/01/rdf-schema#label Boxing .
# http://example.com/sports#hasReferee http://www.w3.org/2000/01/rdf-schema#label Has Referee .
# http://example.com/sports#involvesAthlete http://www.w3.org/2000/01/rdf-schema#label Involves Athlete .
# http://example.com/sports#isJudged http://www.w3.org/2000/01/rdf-schema#label Is Judged .
# http://example.com/sports#requiresSkill http://www.w3.org/2000/01/rdf-schema#label Requires Skill .
# http://example.com/sports#Diving http://www.w3.org/2000/01/rdf-schema#label Diving .
# http://example.com/sports#Swimming http://www.w3.org/2000/01/rdf-schema#label Swimming .
# http://example.com/sports#Wrestling http://www.w3.org/2000/01/rdf-schema#label Wrestling .
# http://example.com/kad/Netherlands http://example.com/kad/contains http://example.com/kad/Belgium .
# http://example.com/kad/Netherlands http://example.com/kad/contains The Netherlands .
# http://example.com/kad/Amsterdam http://example.com/kad/contains http://example.com/kad/Germany .
# http://example.com/sports#Boxing http://example.com/sports#hasReferee Yes .
# http://example.com/sports#Boxing http://example.com/sports#hasSportsProperty Yes .
# http://example.com/sports#Boxing http://www.w3.org/2000/01/rdf-schema#sportsProperty Yes .
# http://example.com/sports#Diving http://example.com/sports#hasReferee Yes .
# http://example.com/sports#Diving http://example.com/sports#hasSportsProperty Yes .
# http://example.com/sports#Diving http://www.w3.org/2000/01/rdf-schema#sportsProperty Yes .
# http://example.com/sports#Swimming http://example.com/sports#hasReferee Yes .
# http://example.com/sports#Swimming http://example.com/sports#hasSportsProperty Yes .
# http://example.com/sports#Swimming http://www.w3.org/2000/01/rdf-schema#sportsProperty Yes .
# http://example.com/sports#Wrestling http://example.com/sports#hasReferee Yes .
# http://example.com/sports#Wrestling http://example.com/sports#hasSportsProperty Yes .
# http://example.com/sports#Wrestling http://www.w3.org/2000/01/rdf-schema#sportsProperty Yes .
# http://example.com/sports#Boxing http://example.com/sports#hasSportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Boxing http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Boxing http://example.com/sports#hasSportsProperty High .
# http://example.com/sports#Boxing http://www.w3.org/2000/01/rdf-schema#sportsProperty High .
# http://example.com/sports#Diving http://example.com/sports#hasSportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Diving http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Diving http://example.com/sports#hasSportsProperty High .
# http://example.com/sports#Diving http://www.w3.org/2000/01/rdf-schema#sportsProperty High .
# http://example.com/sports#Swimming http://example.com/sports#hasSportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Swimming http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Swimming http://example.com/sports#hasSportsProperty Moderate .
# http://example.com/sports#Swimming http://www.w3.org/2000/01/rdf-schema#sportsProperty Moderate .
# http://example.com/sports#Wrestling http://example.com/sports#hasSportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Wrestling http://www.w3.org/2000/01/rdf-schema#sportsProperty http://example.com/sports#involvesAthlete .
# http://example.com/sports#Wrestling http://example.com/sports#hasSportsProperty High .
# http://example.com/sports#Wrestling http://www.w3.org/2000/01/rdf-schema#sportsProperty High .
# http://example.com/sports#Boxing http://example.com/sports#isContact_Sport http://example.com/sports#Sport .
# http://example.com/sports#Wrestling http://example.com/sports#isContact_Sport http://example.com/sports#Sport .
# http://example.com/sports#Boxing http://example.com/sports#isJudged Yes .
# http://example.com/sports#Diving http://example.com/sports#isJudged Yes .
# http://example.com/sports#Swimming http://example.com/sports#isJudged Yes .
# http://example.com/sports#Wrestling http://example.com/sports#isJudged Yes .
# http://example.com/sports#Boxing http://example.com/sports#requiresSkill High .
# http://example.com/sports#Diving http://example.com/sports#requiresSkill High .
# http://example.com/sports#Swimming http://example.com/sports#requiresSkill Moderate .
# http://example.com/sports#Wrestling http://example.com/sports#requiresSkill High .

# %%
# Query 2 - Specify which RDFS rule are you testing:  We are going to test rdfs11

# Check example of Task 1 on how to query remote SPARQL endpoints

sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT DISTINCT ?subclass ?superclass
        WHERE {
            # ?subclass rdfs:subClassOf ?something .
            # ?something rdfs:subClassOf ?superclass .
            FILTER (?subclass != ?superclass)
    }
""")

sparql.setReturnFormat(JSON)
results = sparql.query().convert()
for result in results["results"]["bindings"]:
    subclass = result["subclass"]["value"]
    superclass = result["superclass"]["value"]
    print(f"{subclass} is a subclass of {superclass}")
# Out:
# http://www.w3.org/2001/XMLSchema#nonNegativeInteger is a subclass of http://www.w3.org/2000/01/rdf-schema#Literal
# http://www.w3.org/2000/01/rdf-schema#Datatype is a subclass of http://www.w3.org/2000/01/rdf-schema#Class
# http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty is a subclass of http://www.w3.org/1999/02/22-rdf-syntax-ns#Property
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt is a subclass of http://www.w3.org/2000/01/rdf-schema#Container
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag is a subclass of http://www.w3.org/2000/01/rdf-schema#Container
# http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq is a subclass of http://www.w3.org/2000/01/rdf-schema#Container
# http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral is a subclass of http://www.w3.org/2000/01/rdf-schema#Literal
# http://www.w3.org/2001/XMLSchema#string is a subclass of http://www.w3.org/2000/01/rdf-schema#Literal
# http://example.com/sports#hasReferee is a subclass of http://example.com/sports#Sport
# http://example.com/sports#hasReferee is a subclass of http://example.com/sports#sportsProperty
# http://example.com/sports#involvesAthlete is a subclass of http://example.com/sports#Sport
# http://example.com/sports#involvesAthlete is a subclass of http://example.com/sports#sportsProperty
# http://example.com/sports#isJudged is a subclass of http://example.com/sports#Sport
# http://example.com/sports#isJudged is a subclass of http://example.com/sports#sportsProperty
# http://example.com/sports#requiresSkill is a subclass of http://example.com/sports#Sport
# http://example.com/sports#requiresSkill is a subclass of http://example.com/sports#sportsProperty
# http://example.com/sports#sportsProperty is a subclass of http://example.com/sports#Sport

# %% [markdown]
# ## Submitting the assignment
#
# Please submit this notebook (.ipynb) once you're finished with the assignment. It is not necessary to submit the created turtle files.
